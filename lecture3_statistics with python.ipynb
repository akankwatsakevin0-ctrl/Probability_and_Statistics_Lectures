# %%
import pandas as pd

# %% [markdown]
# ### loading the dataset
# 1. know  the extension (.xlsx, .csv, .json, .parquet)
# 2. know where the file is stored(in the dir, or outside the dir)

# %%
housing = pd.read_csv("Housing.csv") ## in the dir
housing.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
cassava = pd.read_excel("D:\\UCU\\UCU Advent 2025\\Postgraduate\\Data Science Lifecyecle\\Assignment two\\Cassava_Yield_Data.xlsx")

# %%
cassava = pd.read_excel("D:/UCU/UCU Advent 2025/Postgraduate/Data Science Lifecyecle/Assignment two/Cassava_Yield_Data.xlsx")

# %%
housing.tail(20)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 525  2345000  3640         2          1        1      yes        no       no
# 526  2310000  3180         2          1        1      yes        no       no
# 527  2275000  1836         2          1        1       no        no      yes
# 528  2275000  3970         1          1        1       no        no       no
# 529  2275000  3970         3          1        2      yes        no      yes
# 530  2240000  1950         3          1        1       no        no       no
# 531  2233000  5300         3          1        1       no        no       no
# 532  2135000  3000         2          1        1       no        no       no
# 533  2100000  2400         3          1        2      yes        no       no
# 534  2100000  3000         4          1        2      yes        no       no
# 535  2100000  3360         2          1        1      yes        no       no
# ...

# %%
housing.shape ## rows and columns
# Out:
# (545, 13)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# ### Measure of Central tendency

# %%
housing.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
housing["price"].mean()
# Out:
# 4766729.247706422

# %%
housing["price"].median()
# Out:
# 4340000.0

# %%
housing["price"].mode()
# Out:
# 0    3500000
# 1    4200000
# Name: price, dtype: int64

# %% [markdown]
# ### Measures of dispersion

# %% [markdown]
# - range
# - std
# - variance
# - min
# - max
# - iqr

# %%
## min
minimum = housing["price"].min()
minimum
# Out:
# 1750000

# %%
## max
maximum = housing["price"].max()
maximum
# Out:
# 13300000

# %%
## range 
maximum-minimum
# Out:
# 11550000

# %%
### standard deviation
housing["price"].std()
# Out:
# 1870439.6156573922

# %%
# variance
housing["price"].var()
# Out:
# 3498544355820.573

# %%
q1 = housing["price"].quantile(.25) ## lower quantile
q3 = housing["price"].quantile(.75) ## upper quantile
iqr = q3 - q1
iqr
# Out:
# 2310000.0
